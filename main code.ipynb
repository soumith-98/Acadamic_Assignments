# %% [markdown]
# # <center>CSE 4/574: Introduction to Machine Learning</center>
# ## <center>Prof. Sargur Srihari</center>
# ### <center>Assignment 3</center>

# %%
# Imports
import gym
from gym import spaces
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from collections import deque
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()
import random
import seaborn as sns
from IPython.display import Image
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Stock Trading Environment

# %%
# Defining the Stock Trading Environment.
"""DON'T MAKE ANY CHANGES TO THE ENVIRONMENT."""


class StockTradingEnvironment(gym.Env):
    """This class implements the Stock Trading environment."""

    def __init__(self, file_path, train=True, number_of_days_to_consider=10):
        """This method initializes the environment.

        :param file_path: - Path of the CSV file containing the historical stock data.
        :param train: - Boolean indicating whether the goal is to train or test the performance of the agent.
        :param number_of_days_to_consider = Integer representing whether the number of days the for which the agent
                considers the trend in stock price to make a decision."""

        self.file_path = file_path  # Path of the CSV file containing the historical stock data.
        self.stock_data = pd.read_csv(self.file_path)  # Reading the CSV file containing the historical stock data.
        self.train = train  # Boolean indicating to use the training stock data by default.
        # Splitting the data into train and test datasets.
        self.training_stock_data = self.stock_data.iloc[:int(0.8 * len(self.stock_data))]
        self.testing_stock_data = self.stock_data.iloc[int(0.8 * len(self.stock_data)):].reset_index()
        self.observation_space = spaces.Discrete(4)  # This defines that there are four states in the environment.
        # This defines that there are 3 discrete actions that the agent can perform (Buy, Sell, Hold).
        self.action_space = spaces.Discrete(3)
        self.investment_capital = 100000  # This defines the investment capital that the agent starts with.
        self.number_of_shares = 0  # This defines number of shares currently held by the agent.
        self.stock_value = 0  # This defines the value of the stock currently held by the agent.
        self.book_value = 0  # This defines the total value for which the agent bought the shares.
        # This defines the agent's total account value.
        self.total_account_value = self.investment_capital + self.stock_value
        # List to store the total account value over training or evaluation.
        self.total_account_value_list = []
        # This defines the number of days for which the agent considers the data before taking an action.
        self.number_of_days_to_consider = number_of_days_to_consider
        # The maximum timesteps the agent will take before the episode ends.
        if self.train:
            self.max_timesteps = len(self.training_stock_data) - self.number_of_days_to_consider
        else:
            self.max_timesteps = len(self.testing_stock_data) - self.number_of_days_to_consider
        # Initializing the number of steps taken to 0.
        self.timestep = 0
        self.reset()

    def reset(self):
        """This method resets the environment and returns the observation.

        :returns observation: - (Integer in the range of 0 to 3 representing the four possible observations that the
                                 agent can receive. The observation depends upon whether the price increased on average
                                 in the number of days the agent considers, and whether the agent already has the stock
                                 or not.)"""

        self.investment_capital = 100000  # This defines the investment capital that the agent starts with.
        self.number_of_shares = 0  # This defines number of shares currently held by the agent.
        self.stock_value = 0  # This defines the value of the stock currently held by the agent.
        self.book_value = 0  # This defines the total value for which the agent bought the shares.
        # This defines the agent's total account value.
        self.total_account_value = self.investment_capital + self.stock_value
        # List to store the total account value over training or evaluation.
        self.total_account_value_list = []
        # Initializing the number of steps taken to 0.
        self.timestep = 0

        # Getting the observation vector.
        if self.train:
            # If the task is to train the agent the maximum timesteps will be equal to the number of days considered
            # subtracted from the  length of the training stock data.
            self.max_timesteps = len(self.training_stock_data) - self.number_of_days_to_consider

            # Calculating whether the price increased or decreased/remained the same on the majority of days the agent
            # considers.
            price_increase_list = []
            for i in range(self.number_of_days_to_consider):
                if self.training_stock_data['Close'][self.timestep + 1 + i] \
                        - self.training_stock_data['Close'][self.timestep + i] > 0:
                    price_increase_list.append(1)
                else:
                    price_increase_list.append(0)

            if (np.sum(price_increase_list) / self.number_of_days_to_consider) >= 0.5:
                price_increase = 1
                price_decrease = 0
            else:
                price_increase = 0
                price_decrease = 1

            # Observation vector that will be passed to the agent.
            observation = [price_increase, price_decrease, 0, 1]

        else:
            # If the task is to evaluate the trained agent's performance the maximum timesteps will be equal to the
            # number of days considered subtracted from the  length of the testing stock data.
            self.max_timesteps = len(self.testing_stock_data) - self.number_of_days_to_consider

            # Calculating whether the price increased or decreased/remained the same on the majority of days the agent
            # considers.
            price_increase_list = []
            for i in range(self.number_of_days_to_consider):
                if self.testing_stock_data['Close'][self.timestep + 1 + i] \
                        - self.testing_stock_data['Close'][self.timestep + i] > 0:
                    price_increase_list.append(1)
                else:
                    price_increase_list.append(0)

            if (np.sum(price_increase_list) / self.number_of_days_to_consider) >= 0.5:
                price_increase = 1
                price_decrease = 0
            else:
                price_increase = 0
                price_decrease = 1

            # Observation vector.
            observation = [price_increase, price_decrease, 0, 1]
        if np.array_equal(observation, [1, 0, 0, 1]):
            observation = 0
        if np.array_equal(observation, [1, 0, 1, 0]):
            observation = 1
        if np.array_equal(observation, [0, 1, 0, 1]):
            observation = 2
        if np.array_equal(observation, [0, 1, 1, 0]):
            observation = 3

        return observation

    def step(self, action):
        """This method implements what happens when the agent takes the action to Buy/Sell/Hold.

        :param action: - (Integer in the range 0 to 2 inclusive.)

        :returns observation: - (Integer in the range of 0 to 3 representing the four possible observations that the
                                 agent can receive. The observation depends upon whether the price increased on average
                                 in the number of days the agent considers, and whether the agent already has the stock
                                 or not.)
                 reward: - (Integer/Float value that's used to measure the performance of the agent.)
                 done: - (Boolean describing whether or not the episode has ended.)
                 info: - (A dictionary that can be used to provide additional implementation information.)"""

        # We give the agent a penalty for taking actions such as buying a stock when the agent doesn't have the
        # investment capital and selling a stock when the agent doesn't have any shares.
        penalty = 0

        if self.train:
            if action == 0:  # Buy
                if self.number_of_shares > 0:
                    penalty = -10
                # Determining the number of shares the agent can buy.
                number_of_shares_to_buy = math.floor(self.investment_capital / self.training_stock_data[
                    'Open'][self.timestep + self.number_of_days_to_consider])
                # Adding to the number of shares the agent has.
                self.number_of_shares += number_of_shares_to_buy

                # Computing the stock value, book value, investment capital and reward.
                if number_of_shares_to_buy > 0:
                    self.stock_value +=\
                        self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy
                    self.book_value += \
                        self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider]\
                        * number_of_shares_to_buy
                    self.investment_capital -= \
                        self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy

                    reward = 1 + penalty

                else:
                    # Computing the stock value and reward.
                    self.stock_value = \
                        self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * self.number_of_shares
                    reward = -10

            if action == 1:  # Sell
                # Computing the investment capital, sell value and reward.
                self.investment_capital += \
                    self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                    * self.number_of_shares
                sell_value = self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                             * self.number_of_shares

                if self.book_value > 0:
                    reward = (sell_value - self.book_value) / self.book_value * 100
                else:
                    reward = -10

                self.number_of_shares = 0
                self.stock_value = 0
                self.book_value = 0

            if action == 2:  # Hold
                # Computing the stock value and reward.
                self.stock_value = self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                                   * self.number_of_shares

                if self.book_value > 0:
                    reward = (self.stock_value - self.book_value) / self.book_value * 100
                else:
                    reward = -1

        else:
            if action == 0:  # Buy
                if self.number_of_shares > 0:
                    penalty = -10
                # Determining the number of shares the agent can buy.
                number_of_shares_to_buy = math.floor(self.investment_capital / self.testing_stock_data[
                    'Open'][self.timestep + self.number_of_days_to_consider])
                # Adding to the number of shares the agent has.
                self.number_of_shares += number_of_shares_to_buy

                # Computing the stock value, book value, investment capital and reward.
                if number_of_shares_to_buy > 0:
                    self.stock_value += \
                        self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy
                    self.book_value += \
                        self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy
                    self.investment_capital -= \
                        self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                        * number_of_shares_to_buy

                    reward = 1 + penalty

                else:
                    # Computing the stock value and reward.
                    self.stock_value = self.training_stock_data['Open'][
                                           self.timestep + self.number_of_days_to_consider] * self.number_of_shares
                    reward = -10

            if action == 1:  # Sell
                # Computing the investment capital, sell value and reward.
                self.investment_capital += \
                    self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                    * self.number_of_shares
                sell_value = self.training_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                             * self.number_of_shares

                if self.book_value > 0:
                    reward = (sell_value - self.book_value) / self.book_value * 100
                else:
                    reward = -10

                self.number_of_shares = 0
                self.stock_value = 0
                self.book_value = 0

            if action == 2:  # Hold
                # Computing the stock value and reward.
                self.stock_value = self.testing_stock_data['Open'][self.timestep + self.number_of_days_to_consider] \
                                   * self.number_of_shares

                if self.book_value > 0:
                    reward = (self.stock_value - self.book_value) / self.book_value * 100
                else:
                    reward = -1

        # Determining if the agent currently has shares of the stock or not.
        if self.number_of_shares > 0:
            stock_held = 1
            stock_not_held = 0
        else:
            stock_held = 0
            stock_not_held = 1

        # Getting the observation vector.
        if self.train:
            # If the task is to train the agent the maximum timesteps will be equal to the number of days considered
            # subtracted from the  length of the training stock data.
            self.max_timesteps = len(self.training_stock_data) - self.number_of_days_to_consider

            # Calculating whether the price increased or decreased/remained the same on the majority of days the agent
            # considers.
            price_increase_list = []
            for i in range(self.number_of_days_to_consider):
                if self.training_stock_data['Close'][self.timestep + 1 + i] \
                        - self.training_stock_data['Close'][self.timestep + i] > 0:
                    price_increase_list.append(1)
                else:
                    price_increase_list.append(0)

            if (np.sum(price_increase_list) / self.number_of_days_to_consider) >= 0.5:
                price_increase = 1
                price_decrease = 0
            else:
                price_increase = 0
                price_decrease = 1

            # Observation vector.
            observation = [price_increase, price_decrease, stock_held, stock_not_held]

        else:
            # If the task is to evaluate the trained agent's performance the maximum timesteps will be equal to the
            # number of days considered subtracted from the  length of the testing stock data.
            self.max_timesteps = len(self.testing_stock_data) - self.number_of_days_to_consider

            # Calculating whether the price increased or decreased/remained the same on the majority of days the agent
            # considers.
            price_increase_list = []
            for i in range(self.number_of_days_to_consider):
                if self.testing_stock_data['Close'][self.timestep + 1 + i] \
                        - self.testing_stock_data['Close'][self.timestep + i] > 0:
                    price_increase_list.append(1)
                else:
                    price_increase_list.append(0)

            if (np.sum(price_increase_list) / self.number_of_days_to_consider) >= 0.5:
                price_increase = 1
                price_decrease = 0
            else:
                price_increase = 0
                price_decrease = 1

            # Observation vector.
            observation = [price_increase, price_decrease, stock_held, stock_not_held]

        self.timestep += 1  # Increasing the number of steps taken by the agent by 1.

        if np.array_equal(observation, [1, 0, 0, 1]):
            observation = 0
        if np.array_equal(observation, [1, 0, 1, 0]):
            observation = 1
        if np.array_equal(observation, [0, 1, 0, 1]):
            observation = 2
        if np.array_equal(observation, [0, 1, 1, 0]):
            observation = 3

        # Computing the total account value.
        self.total_account_value = self.investment_capital + self.stock_value
        # Appending the total account value of the list to plot the graph.
        self.total_account_value_list.append(self.total_account_value)

        # The episode terminates when the number of infected people becomes greater than 75 % of the population.
        done = True if (self.timestep >= self.max_timesteps) \
            else False

        info = {}
        return observation, reward, done, info

    def render(self, mode='human'):
        """This method renders the agent's total account value over time.

        :param mode: 'human' renders to the current display or terminal and returns nothing."""

        plt.figure(figsize=(15, 10))
        plt.plot(self.total_account_value_list, color='lightseagreen', linewidth=7)
        plt.xlabel('Days', fontsize=32)
        plt.ylabel('Total Account Value', fontsize=32)
        plt.title('Total Account Value over Time', fontsize=38)
        plt.grid()
        plt.show()

# %% [markdown]
# ### TO DO: Implement the Q-learning algorithm

# %%
data=pd.read_csv("NVDA.csv")

# %%
# Implementing Q-Learning for the stock trading environment.
df= data.copy()
class QLearning:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []
        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())
    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))
                
            #agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
    def evaluate(self):
        """This method evaluate the trained agent's performance."""

        """"TO DO: Evaluate the trained agent's performance by selecting only the greedy/best action in each state."""
        self.environment.train = False
        #states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

    def plot(self,):
        """This method plots the reward dynamics and epsilon decay."""

        """TO DO: Plot the total reward per episode and epsilon decay when training."""
        fig = plt.figure(figsize = (15,5))
        plt.plot(close, color='r', lw=2.)
        plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
        plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
        plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
        plt.legend()
        plt.show()
        
        plt.figure(figsize=(10,6))
        window = 10
        plt.grid(True)
        plt.xlabel('Episode',fontsize=15)
        plt.ylabel('Total Reward (SMA 10)',fontsize=15)
        plt.plot([np.mean(total_reward[tr:tr+window]) for tr in range(window, len(avg_score))])
        plt.title("Total Reward over epsiodes.",fontsize=15)
        plt.savefig('img1.pdf')
        
        plt.figure(figsize=(24,6))
        plt.xlabel('Episode',fontsize=15)
        plt.ylabel('$\epsilon$',fontsize=15)
        plt.plot(epsilons)
        plt.grid(True)
        plt.title("Epsilon Decay",fontsize=15)
        plt.savefig('img2.png')

# %%
close = data.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = QLearning(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# epoch: 10, total rewards: 24.750031.3, cost: 0.396258, total money: 10024.750031
# epoch: 20, total rewards: 37.080024.3, cost: 0.285613, total money: 10037.080024
# epoch: 30, total rewards: 25.117506.3, cost: 0.226435, total money: 10025.117506
# epoch: 40, total rewards: 27.265038.3, cost: 0.188305, total money: 10027.265038
# epoch: 50, total rewards: 22.885019.3, cost: 0.162109, total money: 10022.885019
# epoch: 60, total rewards: -2.437488.3, cost: 0.149951, total money: 9997.562512
# epoch: 70, total rewards: 15.665016.3, cost: 0.165780, total money: 10015.665016
# epoch: 80, total rewards: 19.420016.3, cost: 0.112817, total money: 10019.420016
# epoch: 90, total rewards: 20.105005.3, cost: 0.104231, total money: 10020.105005
# epoch: 100, total rewards: 26.287529.3, cost: 0.095965, total money: 10026.287529
# epoch: 110, total rewards: 21.312497.3, cost: 0.089166, total money: 10021.312497
# epoch: 120, total rewards: 27.967507.3, cost: 0.083223, total money: 10027.967507
# epoch: 130, total rewards: 14.222479.3, cost: 0.078207, total money: 10014.222479
# epoch: 140, total rewards: 24.784996.3, cost: 0.072904, total money: 10024.784996
# epoch: 150, total rewards: 49.822496.3, cost: 0.068119, total money: 10049.822496
# epoch: 160, total rewards: 15.919977.3, cost: 0.064041, total money: 10015.919977
# epoch: 170, total rewards: 55.489989.3, cost: 0.060644, total money: 10055.489989
# epoch: 180, total rewards: 35.399988.3, cost: 0.057019, total money: 10035.399988
# epoch: 190, total rewards: 40.522471.3, cost: 0.053494, total money: 10040.522471
# epoch: 200, total rewards: 38.802489.3, cost: 0.050499, total money: 10038.802489

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 17.670000, total balance 9982.330000
# day 2, sell 1 unit at price 17.790001, investment 0.679123 %, total balance 10000.120001,
# day 15: buy 1 unit at price 23.097500, total balance 9977.022501
# day 18, sell 1 unit at price 23.412500, investment 1.363784 %, total balance 10000.435001,
# day 27: buy 1 unit at price 23.347500, total balance 9977.087501
# day 28, sell 1 unit at price 23.767500, investment 1.798908 %, total balance 10000.855001,
# day 51: buy 1 unit at price 26.290001, total balance 9974.565000
# day 54, sell 1 unit at price 25.277500, investment -3.851278 %, total balance 9999.842500,
# day 57: buy 1 unit at price 26.002501, total balance 9973.839999
# day 60, sell 1 unit at price 26.947500, investment 3.634262 %, total balance 10000.787499,
# day 70: buy 1 unit at price 29.652500, total balance 9971.134999
# day 71, sell 1 unit at price 29.094999, investment -1.880115 %, total balance 10000.229998,
# day 79: buy 1 unit at price 27.690001, total balance 9972.539997
# day 80, sell 1 unit at price 25.122499, investment -9.272307 %, total balance 9997.662496,
# day 97: buy 1 unit at price 27.362499, total balance 9970.299997
# day 98, sell 1 unit at price 26.477501, investment -3.234346 %, total balance 9996.777498,
# day 103: buy 1 unit at price 26.922501, total balance 9969.854997
# day 105, sell 1 unit at price 27.350000, investment 1.587887 %, total balance 9997.204997,
# day 107: buy 1 unit at price 27.094999, total balance 9970.109998
# day 108, sell 1 unit at price 25.195000, investment -7.012360 %, total balance 9995.304998,
# day 111: buy 1 unit at price 25.082500, total balance 9970.222498
# day 112, sell 1 unit at price 24.442499, investment -2.551584 %, total balance 9994.664997,
# day 115: buy 1 unit at price 23.872499, total balance 9970.792498
# day 118, sell 1 unit at price 24.920000, investment 4.387898 %, total balance 9995.712498,
# day 128: buy 1 unit at price 26.062500, total balance 9969.649998
# day 133, sell 1 unit at price 30.322500, investment 16.345324 %, total balance 9999.972498,
# day 135: buy 1 unit at price 31.972500, total balance 9967.999998
# day 137: buy 1 unit at price 34.202499, total balance 9933.797499
# day 138: buy 1 unit at price 31.930000, total balance 9901.867499
# day 140, sell 1 unit at price 34.000000, investment 6.341387 %, total balance 9935.867499,
# day 141, sell 1 unit at price 34.724998, investment 1.527663 %, total balance 9970.592497,
# day 143: buy 1 unit at price 34.642502, total balance 9935.949995
# day 147, sell 1 unit at price 36.087502, investment 13.020676 %, total balance 9972.037497,
# day 148, sell 1 unit at price 36.090000, investment 4.178388 %, total balance 10008.127497,
# day 158: buy 1 unit at price 38.092499, total balance 9970.034998
# day 159, sell 1 unit at price 37.904999, investment -0.492223 %, total balance 10007.939997,
# day 171: buy 1 unit at price 35.762501, total balance 9972.177496
# day 173, sell 1 unit at price 36.689999, investment 2.593493 %, total balance 10008.867495,
# day 176: buy 1 unit at price 40.627499, total balance 9968.239996
# day 178, sell 1 unit at price 41.237499, investment 1.501446 %, total balance 10009.477495,
# day 192: buy 1 unit at price 41.619999, total balance 9967.857496
# day 194, sell 1 unit at price 43.087502, investment 3.525956 %, total balance 10010.944998,
# day 204: buy 1 unit at price 39.787498, total balance 9971.157500
# day 207, sell 1 unit at price 41.297501, investment 3.795170 %, total balance 10012.455001,
# day 220: buy 1 unit at price 42.592499, total balance 9969.862502
# day 221, sell 1 unit at price 42.349998, investment -0.569351 %, total balance 10012.212500,
# day 224: buy 1 unit at price 46.837502, total balance 9965.374998
# day 226, sell 1 unit at price 45.189999, investment -3.517487 %, total balance 10010.564997,
# day 234: buy 1 unit at price 44.842499, total balance 9965.722498
# day 237, sell 1 unit at price 45.325001, investment 1.075993 %, total balance 10011.047499,
# day 254: buy 1 unit at price 51.702499, total balance 9959.345000
# day 256: buy 1 unit at price 51.485001, total balance 9907.859999
# day 259, sell 1 unit at price 53.007500, investment 2.524058 %, total balance 9960.867499,
# day 260, sell 1 unit at price 52.290001, investment 1.563562 %, total balance 10013.157500,
# day 267: buy 1 unit at price 52.840000, total balance 9960.317500
# day 269, sell 1 unit at price 54.012501, investment 2.218965 %, total balance 10014.330001,
# day 281: buy 1 unit at price 47.872501, total balance 9966.457500
# day 282, sell 1 unit at price 48.665001, investment 1.655439 %, total balance 10015.122501,
# day 283: buy 1 unit at price 47.709999, total balance 9967.412502
# day 284, sell 1 unit at price 46.544998, investment -2.441838 %, total balance 10013.957500,
# day 297: buy 1 unit at price 53.117500, total balance 9960.840000
# day 298, sell 1 unit at price 53.397499, investment 0.527131 %, total balance 10014.237499,
# day 301: buy 1 unit at price 55.485001, total balance 9958.752498
# day 303, sell 1 unit at price 56.020000, investment 0.964223 %, total balance 10014.772498,
# day 305: buy 1 unit at price 55.027500, total balance 9959.744998
# day 309, sell 1 unit at price 58.422501, investment 6.169644 %, total balance 10018.167499,
# day 318: buy 1 unit at price 58.380001, total balance 9959.787498
# day 320, sell 1 unit at price 56.395000, investment -3.400139 %, total balance 10016.182498,
# day 339: buy 1 unit at price 60.540001, total balance 9955.642497
# day 341, sell 1 unit at price 60.294998, investment -0.404696 %, total balance 10015.937495,
# day 345: buy 1 unit at price 62.185001, total balance 9953.752494
# day 347, sell 1 unit at price 62.619999, investment 0.699522 %, total balance 10016.372493,
# day 360: buy 1 unit at price 55.345001, total balance 9961.027492
# day 361: buy 1 unit at price 53.562500, total balance 9907.464992
# day 362, sell 1 unit at price 53.852501, investment -2.696721 %, total balance 9961.317493,
# day 363: buy 1 unit at price 56.977501, total balance 9904.339992
# day 366, sell 1 unit at price 57.875000, investment 8.051342 %, total balance 9962.214992,
# day 367, sell 1 unit at price 57.872501, investment 1.570795 %, total balance 10020.087493,
# day 374: buy 1 unit at price 54.165001, total balance 9965.922492
# day 375, sell 1 unit at price 56.305000, investment 3.950889 %, total balance 10022.227492,
# day 379: buy 1 unit at price 56.577499, total balance 9965.649993
# day 380, sell 1 unit at price 58.247501, investment 2.951707 %, total balance 10023.897494,
# day 384: buy 1 unit at price 63.945000, total balance 9959.952494
# day 385, sell 1 unit at price 65.032501, investment 1.700682 %, total balance 10024.984995,
# day 394: buy 1 unit at price 61.884998, total balance 9963.099997
# day 395, sell 1 unit at price 61.922501, investment 0.060601 %, total balance 10025.022498,
# day 398: buy 1 unit at price 63.247501, total balance 9961.774997
# day 399, sell 1 unit at price 63.047501, investment -0.316218 %, total balance 10024.822498,
# day 414: buy 1 unit at price 64.277496, total balance 9960.545002
# day 416, sell 1 unit at price 59.779999, investment -6.997001 %, total balance 10020.325001,
# day 419: buy 1 unit at price 60.215000, total balance 9960.110001
# day 420, sell 1 unit at price 59.224998, investment -1.644112 %, total balance 10019.334999,
# day 438: buy 1 unit at price 63.709999, total balance 9955.625000
# day 440, sell 1 unit at price 61.032501, investment -4.202634 %, total balance 10016.657501,
# day 442: buy 1 unit at price 61.617500, total balance 9955.040001
# day 443, sell 1 unit at price 62.654999, investment 1.683773 %, total balance 10017.695000,
# day 460: buy 1 unit at price 68.974998, total balance 9948.720002
# day 464, sell 1 unit at price 70.169998, investment 1.732512 %, total balance 10018.890000,
# day 473: buy 1 unit at price 69.107498, total balance 9949.782502
# day 474: buy 1 unit at price 68.482498, total balance 9881.300004
# day 478, sell 1 unit at price 65.862503, investment -4.695576 %, total balance 9947.162507,
# day 479, sell 1 unit at price 66.425003, investment -3.004410 %, total balance 10013.587510,
# day 495: buy 1 unit at price 61.457500, total balance 9952.130010
# day 496, sell 1 unit at price 60.764999, investment -1.126797 %, total balance 10012.895009,
# day 498: buy 1 unit at price 57.292500, total balance 9955.602509
# day 500, sell 1 unit at price 55.264999, investment -3.538859 %, total balance 10010.867508,
# day 521: buy 1 unit at price 36.177502, total balance 9974.690006
# day 522, sell 1 unit at price 36.250000, investment 0.200395 %, total balance 10010.940006,
# day 526: buy 1 unit at price 39.340000, total balance 9971.600006
# day 527: buy 1 unit at price 40.857498, total balance 9930.742508
# day 528, sell 1 unit at price 42.509998, investment 8.057951 %, total balance 9973.252506,
# day 529, sell 1 unit at price 39.277500, investment -3.867094 %, total balance 10012.530006,
# day 542: buy 1 unit at price 31.770000, total balance 9980.760006
# day 544, sell 1 unit at price 32.792500, investment 3.218445 %, total balance 10013.552506,
# day 546: buy 1 unit at price 33.375000, total balance 9980.177506
# day 547, sell 1 unit at price 34.055000, investment 2.037453 %, total balance 10014.232506,
# day 557: buy 1 unit at price 37.209999, total balance 9977.022507
# day 558, sell 1 unit at price 37.930000, investment 1.934966 %, total balance 10014.952507,
# day 568: buy 1 unit at price 36.182499, total balance 9978.770008
# day 570: buy 1 unit at price 37.487499, total balance 9941.282509
# day 571: buy 1 unit at price 38.250000, total balance 9903.032509
# day 573, sell 1 unit at price 37.042500, investment 2.376842 %, total balance 9940.075009,
# day 574, sell 1 unit at price 36.612499, investment -2.334111 %, total balance 9976.687508,
# day 575, sell 1 unit at price 37.792500, investment -1.196078 %, total balance 10014.480008,
# day 592: buy 1 unit at price 37.660000, total balance 9976.820008
# day 594, sell 1 unit at price 40.630001, investment 7.886354 %, total balance 10017.450009,
# day 596: buy 1 unit at price 41.389999, total balance 9976.060010
# day 597, sell 1 unit at price 42.452499, investment 2.567045 %, total balance 10018.512509,
# day 609: buy 1 unit at price 45.750000, total balance 9972.762509
# day 610, sell 1 unit at price 47.154999, investment 3.071036 %, total balance 10019.917508,
# day 624: buy 1 unit at price 47.792500, total balance 9972.125008
# day 626, sell 1 unit at price 44.522499, investment -6.842080 %, total balance 10016.647507,
# day 640: buy 1 unit at price 40.047501, total balance 9976.600006
# day 641, sell 1 unit at price 39.132500, investment -2.284789 %, total balance 10015.732506,
# day 648: buy 1 unit at price 35.084999, total balance 9980.647507
# day 651, sell 1 unit at price 33.445000, investment -4.674360 %, total balance 10014.092507,
# day 654: buy 1 unit at price 35.945000, total balance 9978.147507
# day 655, sell 1 unit at price 36.375000, investment 1.196272 %, total balance 10014.522507,
# day 657: buy 1 unit at price 37.687500, total balance 9976.835007
# day 658, sell 1 unit at price 36.549999, investment -3.018245 %, total balance 10013.385006,
# day 659: buy 1 unit at price 37.064999, total balance 9976.320007
# day 660, sell 1 unit at price 36.160000, investment -2.441654 %, total balance 10012.480007,
# day 664: buy 1 unit at price 38.525002, total balance 9973.955005
# day 665, sell 1 unit at price 37.939999, investment -1.518502 %, total balance 10011.895004,
# day 667: buy 1 unit at price 37.869999, total balance 9974.025005
# day 668: buy 1 unit at price 39.814999, total balance 9934.210006
# day 669, sell 1 unit at price 40.807499, investment 7.756800 %, total balance 9975.017505,
# day 670, sell 1 unit at price 41.057499, investment 3.120683 %, total balance 10016.075004,
# day 701: buy 1 unit at price 39.012501, total balance 9977.062503
# day 702, sell 1 unit at price 37.517502, investment -3.832102 %, total balance 10014.580005,
# day 703: buy 1 unit at price 37.192501, total balance 9977.387504
# day 705: buy 1 unit at price 42.695000, total balance 9934.692504
# day 706: buy 1 unit at price 41.967499, total balance 9892.725005
# day 707, sell 1 unit at price 42.807499, investment 15.097124 %, total balance 9935.532504,
# day 708, sell 1 unit at price 42.869999, investment 0.409882 %, total balance 9978.402503,
# day 714, sell 1 unit at price 41.877499, investment -0.214452 %, total balance 10020.280002,
# day 721: buy 1 unit at price 46.082500, total balance 9974.197502
# day 724, sell 1 unit at price 45.052502, investment -2.235117 %, total balance 10019.250004,
# day 729: buy 1 unit at price 43.709999, total balance 9975.540005
# day 730, sell 1 unit at price 43.132500, investment -1.321206 %, total balance 10018.672505,
# day 746: buy 1 unit at price 48.552502, total balance 9970.120003
# day 749, sell 1 unit at price 49.002499, investment 0.926826 %, total balance 10019.122502,
# day 750: buy 1 unit at price 48.902500, total balance 9970.220002
# day 751, sell 1 unit at price 48.772499, investment -0.265837 %, total balance 10018.992501,
# day 753: buy 1 unit at price 51.134998, total balance 9967.857503
# day 754, sell 1 unit at price 51.697498, investment 1.100029 %, total balance 10019.555001,
# day 790: buy 1 unit at price 57.377499, total balance 9962.177502
# day 791, sell 1 unit at price 58.865002, investment 2.592485 %, total balance 10021.042504,
# day 803: buy 1 unit at price 60.095001, total balance 9960.947503
# day 804, sell 1 unit at price 60.755001, investment 1.098261 %, total balance 10021.702504,
# day 806: buy 1 unit at price 62.994999, total balance 9958.707505
# day 807, sell 1 unit at price 61.820000, investment -1.865226 %, total balance 10020.527505,
# day 825: buy 1 unit at price 65.742500, total balance 9954.785005
# day 826, sell 1 unit at price 66.972504, investment 1.870942 %, total balance 10021.757509,
# day 830: buy 1 unit at price 74.142502, total balance 9947.615007
# day 831, sell 1 unit at price 78.675003, investment 6.113229 %, total balance 10026.290010,
# day 860: buy 1 unit at price 65.900002, total balance 9960.390008
# day 861, sell 1 unit at price 60.767502, investment -7.788315 %, total balance 10021.157510,
# day 927: buy 1 unit at price 98.717499, total balance 9922.440011
# day 929, sell 1 unit at price 105.089996, investment 6.455286 %, total balance 10027.530007,
# day 941: buy 1 unit at price 104.214996, total balance 9923.315011
# day 942, sell 1 unit at price 102.154999, investment -1.976680 %, total balance 10025.470010,
# day 955: buy 1 unit at price 115.639999, total balance 9909.830011
# day 956, sell 1 unit at price 123.370003, investment 6.684542 %, total balance 10033.200014,
# day 961: buy 1 unit at price 127.202499, total balance 9905.997515
# day 963, sell 1 unit at price 127.730003, investment 0.414696 %, total balance 10033.727518,
# day 972: buy 1 unit at price 127.150002, total balance 9906.577516
# day 973, sell 1 unit at price 123.117500, investment -3.171453 %, total balance 10029.695016,
# day 997: buy 1 unit at price 140.952499, total balance 9888.742517
# day 999: buy 1 unit at price 138.115005, total balance 9750.627512
# day 1000, sell 1 unit at price 134.977493, investment -4.239021 %, total balance 9885.605005,
# day 1002, sell 1 unit at price 135.247498, investment -2.076173 %, total balance 10020.852503,
# day 1022: buy 1 unit at price 134.287506, total balance 9886.564997
# day 1025, sell 1 unit at price 131.399994, investment -2.150246 %, total balance 10017.964991,
# day 1043: buy 1 unit at price 132.720001, total balance 9885.244990
# day 1044, sell 1 unit at price 133.322495, investment 0.453959 %, total balance 10018.567485,
# day 1052: buy 1 unit at price 131.134995, total balance 9887.432490
# day 1054, sell 1 unit at price 126.144997, investment -3.805237 %, total balance 10013.577487,
# day 1068: buy 1 unit at price 129.177505, total balance 9884.399982
# day 1072, sell 1 unit at price 135.567505, investment 4.946682 %, total balance 10019.967487,
# day 1074: buy 1 unit at price 136.642502, total balance 9883.324985
# day 1075, sell 1 unit at price 135.910004, investment -0.536069 %, total balance 10019.234989,
# day 1094: buy 1 unit at price 124.614998, total balance 9894.619991
# day 1097, sell 1 unit at price 124.682503, investment 0.054171 %, total balance 10019.302494,
# day 1113: buy 1 unit at price 138.117493, total balance 9881.185001
# day 1114, sell 1 unit at price 139.875000, investment 1.272472 %, total balance 10021.060001,
# day 1119: buy 1 unit at price 152.089996, total balance 9868.970005
# day 1120, sell 1 unit at price 156.794998, investment 3.093564 %, total balance 10025.765003,
# day 1130: buy 1 unit at price 153.817505, total balance 9871.947498
# day 1131: buy 1 unit at price 152.767502, total balance 9719.179996
# day 1133, sell 1 unit at price 150.095001, investment -2.420078 %, total balance 9869.274997,
# day 1134, sell 1 unit at price 148.367493, investment -2.880200 %, total balance 10017.642490,
# day 1138: buy 1 unit at price 148.122498, total balance 9869.519992
# day 1139, sell 1 unit at price 142.657501, investment -3.689512 %, total balance 10012.177493,
# day 1151: buy 1 unit at price 157.000000, total balance 9855.177493
# day 1152: buy 1 unit at price 154.880005, total balance 9700.297488
# day 1155, sell 1 unit at price 167.782501, investment 6.867835 %, total balance 9868.079989,
# day 1157: buy 1 unit at price 175.782501, total balance 9692.297488
# day 1158, sell 1 unit at price 176.190002, investment 13.759037 %, total balance 9868.487490,
# day 1160, sell 1 unit at price 173.582504, investment -1.251545 %, total balance 10042.069994,
# day 1163: buy 1 unit at price 180.187500, total balance 9861.882494
# day 1164, sell 1 unit at price 177.884995, investment -1.277838 %, total balance 10039.767489,
# day 1191: buy 1 unit at price 195.580002, total balance 9844.187487
# day 1194, sell 1 unit at price 195.029999, investment -0.281216 %, total balance 10039.217486,
# day 1212: buy 1 unit at price 219.580002, total balance 9819.637484
# day 1214: buy 1 unit at price 222.130005, total balance 9597.507479
# day 1216, sell 1 unit at price 226.360001, investment 3.087712 %, total balance 9823.867480,
# day 1218, sell 1 unit at price 223.850006, investment 0.774322 %, total balance 10047.717486,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
Image(url="images/img1.png")
# Out:
# <img src="images/img1.png"/>

# %%
Image(url="images/img2.png")
# Out:
# <img src="images/img2.png"/>

# %%
stock_trading_environment = StockTradingEnvironment('./NVDA.csv', number_of_days_to_consider=10)
